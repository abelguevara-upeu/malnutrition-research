# %% [markdown]
# # 🔍 Visor Interactivo de Datos SPSS (Data Viewer)
# Este notebook es una herramienta de utilidad. Sirve para cargar rápidamente cualquier módulo de un año específico de la ENDES y visualizarlo de manera "Human-Readable".
#
# **Funciones automáticas de este visor:**
# 1. **Columnas:** Muestra el nombre de la variable y justo debajo su etiqueta descriptiva.
# 2. **Valores:** Si una variable es categórica (ej: 1, 2, 3), concatena su significado original al lado del número (ej: `1.0 (Urbano)`).

# %%
from mnp.ingestion.loader import display_endes
# Out:
# 2026-06-01 21:00:16.799 | INFO     | mnp.config:<module>:11 - PROJ_ROOT path is: /Users/abelguevarah/Desktop/invs/malnutrition-research

# %%
# columnas_a_ver = ['HV024', 'HV025', 'HV026']
# raw / native / enriched
_, _ = display_endes(
    year=2007,
    module='household',
    record='household_characteristics',
    rows_per_page=3,
    view_mode='enriched'
)
# Out:
# 2026-06-01 21:00:18.650 | INFO     | mnp.ingestion.loader:load_endes:375 - ✓ Cargando registro: RECH0.SAV desde Modulo64 [Alias: household_characteristics]
# 2026-06-01 21:00:18.964 | INFO     | mnp.ingestion.loader:display_endes:422 - Visor interactivo activado. 29336 registros distribuidos en 9779 páginas.
# BoundedIntText(value=1, description='Page (of 9779):', max=9779, min=1, style=DescriptionStyle(description_wid…
# Output()
