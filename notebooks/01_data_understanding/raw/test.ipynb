# %%
from mnp.ingestion.loader import load_endes
df, meta = load_endes(year=2018, module='household', record='rech0', meta=True)

print(type(df))
print(type(meta))
print(type(meta.column_labels))
print(type(meta.column_names))
print(type(meta.value_labels))
# Out:
# 2026-06-07 23:20:34.015 | INFO     | mnp.config:<module>:11 - PROJ_ROOT path is: /workspace
# OpenBLAS WARNING - could not determine the L2 cache size on this system, assuming 256k
# 2026-06-07 23:20:34.737 | INFO     | mnp.ingestion.loader:load_endes:375 - ✓ Cargando registro: RECH0.SAV desde Modulo64 [Alias: household_characteristics]
# <class 'pandas.DataFrame'>
# <class 'pyreadstat.pyclasses.metadata_container'>
# <class 'list'>
# <class 'list'>
# <class 'dict'>

# %%
print(type(list(meta.variable_value_labels['HV020'].keys())[1]))
print(type(meta.variable_value_labels['HV020'][1.0]))

# print(type(list(meta.value_labels)))

# print(type(list(meta.value_labels['labels0'].values())[0]))

# for n, t in list(meta.value_labels.items())[:3]:
#     print(n, type(n))
#     print(t, type(t))
# Out:
# <class 'float'>
# <class 'str'>
